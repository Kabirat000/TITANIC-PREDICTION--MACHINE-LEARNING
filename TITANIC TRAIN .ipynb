# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")
sns.set_style('whitegrid')

# %%
DATA = pd.read_csv('titanic_train.csv')

# %%
DATA.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
DATA.duplicated().sum()
# Out:
# 0

# %%
DATA.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
DATA.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
DATA.drop('Cabin', axis=1, inplace=True)

# %%
DATA
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
DATA.drop('Ticket', axis=1, inplace=True)

# %%
DATA.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#sns.heatmap(DATA.corr(), annot=True) # correlation for data visuals
DATA.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
DATA[DATA['Survived']==1]['Age'].mode() #age of those that survived
# Out:
# 0    24.0
# dtype: float64

# %%
DATA[DATA['Survived']==0]['Age'].mode()
# Out:
# 0    21.0
# dtype: float64

# %%
DATA['Age'] = DATA['Age'].fillna(DATA[DATA['Survived']==1]['Age'].mode())

# %%
DATA['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
DATA['Age'].isnull().sum()
# Out:
# 177

# %%
#if DATA['Age'].isna()==True & DATA['Survived']==1:
#    DATA['Age'] = DATA['Age'].fillna(24)
#else:
#    DATA['Age'] = DATA['Age'].fillna(21)

# %%
condition = (DATA['Age'].isna()) & (DATA['Survived'] == 1)
DATA['Age'] = DATA['Age'].fillna(24).where(condition, DATA['Age'].fillna(21))

# %%
DATA['Age'].isnull().sum()
# Out:
# 0

# %%
#DATA.dropna('Embarked', axis=0, inplace=True) #0 is row,1 is column
DATA.dropna(inplace=True)

# %%
DATA.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
DATA
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
DATA = pd.get_dummies(DATA,columns=['Sex','Embarked']) #should be before model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
DATA.drop(['PassengerId', 'Name'], axis=1, inplace=True) #should be before model

# %%
X = DATA.drop('Survived', axis=1)
y = DATA['Survived']

# %%
DATA
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0    7.2500           0         1
# 1           1       1  38.0      1      0   71.2833           1         0
# 2           1       3  26.0      0      0    7.9250           1         0
# 3           1       1  35.0      1      0   53.1000           1         0
# 4           0       3  35.0      0      0    8.0500           0         1
# 5           0       3  21.0      0      0    8.4583           0         1
# 6           0       1  54.0      0      0   51.8625           0         1
# 7           0       3   2.0      3      1   21.0750           0         1
# 8           1       3  27.0      0      2   11.1333           1         0
# 9           1       2  14.0      1      0   30.0708           1         0
# 10          1       3   4.0      1      1   16.7000           1         0
# 11          1       1  58.0      0      0   26.5500           1         0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8164794007490637

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.91      0.86       163
#           1       0.82      0.67      0.74       104
#
# avg / total       0.82      0.82      0.81       267

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[148  15]
#  [ 34  70]]

# %%
#sns.countplot(x='Sex', hue ='Survived', data= DATA, palette='RdBu') it is EDA
sns.countplot(x='Pclass', hue ='Survived', data= DATA, palette='RdBu')

# %%
DATA
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0    7.2500           0         1
# 1           1       1  38.0      1      0   71.2833           1         0
# 2           1       3  26.0      0      0    7.9250           1         0
# 3           1       1  35.0      1      0   53.1000           1         0
# 4           0       3  35.0      0      0    8.0500           0         1
# 5           0       3  21.0      0      0    8.4583           0         1
# 6           0       1  54.0      0      0   51.8625           0         1
# 7           0       3   2.0      3      1   21.0750           0         1
# 8           1       3  27.0      0      2   11.1333           1         0
# 9           1       2  14.0      1      0   30.0708           1         0
# 10          1       3   4.0      1      1   16.7000           1         0
# 11          1       1  58.0      0      0   26.5500           1         0
# ...

# %%
NEW_DATA = DATA #IFYOUWANTBUILDDIFFMODELSUSINGSAME DATA BUT RENAME 
NEW_DATA.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0         0       3  22.0      1      0   7.2500           0         1
# 1         1       1  38.0      1      0  71.2833           1         0
# 2         1       3  26.0      0      0   7.9250           1         0
# 3         1       1  35.0      1      0  53.1000           1         0
# 4         0       3  35.0      0      0   8.0500           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
#importing the required library for scaling
from sklearn.preprocessing import StandardScaler #to scale variables to close values btw independent variables

# %%
Scaler = StandardScaler()#initialiazing the library

# %%
#scaling the independent variables
Scaler.fit(NEW_DATA.drop('Survived', axis=1))# we dont want to scale survive cos itss dependent
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
Scaled_features = Scaler.transform(NEW_DATA.drop('Survived',axis=1)) 
#getting the scaled values

# %%
#NEW_DATA_feat=pd.DataFrame(Scaled_features,columns=NEW_DATA.columns[:-1])
#NEW_DATA_feat.head()
#creating a dataframe

# %%
NEW_DATA.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_female',
#        'Sex_male', 'Embarked_C', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
NEW_DATA_feat=pd.DataFrame(Scaled_features,columns=[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_female',
       'Sex_male', 'Embarked_C', 'Embarked_Q', 'Embarked_S']])

# %%
NEW_DATA_feat.head()
# Out:
#      Pclass       Age     SibSp     Parch      Fare Sex_female  Sex_male  \
# 0  0.825209 -0.457030  0.431350 -0.474326 -0.500240  -0.735342  0.735342
# 1 -1.572211  0.742340  0.431350 -0.474326  0.788947   1.359911 -1.359911
# 2  0.825209 -0.157187 -0.475199 -0.474326 -0.486650   1.359911 -1.359911
# 3 -1.572211  0.517458  0.431350 -0.474326  0.422861   1.359911 -1.359911
# 4  0.825209  0.517458 -0.475199 -0.474326 -0.484133  -0.735342  0.735342
#
#   Embarked_C Embarked_Q Embarked_S
# 0  -0.482711  -0.307941   0.616794
# 1   2.071634  -0.307941  -1.621287
# 2  -0.482711  -0.307941   0.616794
# 3  -0.482711  -0.307941   0.616794
# 4  -0.482711  -0.307941   0.616794

# %% [markdown]
# # train test split

# %%
#from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Scaled_features, NEW_DATA['Survived'], test_size=0.30, random_state=101)

# %% [markdown]
# # USING KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %%
pred = knn.predict(X_test)

# %% [markdown]
# # prediction and evaluations
# lets evaluate our KNN model

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[128  35]
#  [ 25  79]]

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8164794007490637

# %% [markdown]
# # choosing a k value
# this should be done before getting your accuracy

# %%
error_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')

# %%
error_rate
# Out:
# [0.2247191011235955,
#  0.19850187265917604,
#  0.18352059925093633,
#  0.18352059925093633,
#  0.17228464419475656,
#  0.1647940074906367,
#  0.15730337078651685,
#  0.16853932584269662,
#  0.1647940074906367,
#  0.1760299625468165,
#  0.1760299625468165,
#  0.1647940074906367,
#  0.15730337078651685,
#  0.16853932584269662,
#  0.17228464419475656,
#  0.1760299625468165,
#  0.1760299625468165,
#  0.17228464419475656,
#  0.1760299625468165,
#  0.16853932584269662,
#  0.16853932584269662,
#  0.1760299625468165,
#  0.18352059925093633,
#  0.1760299625468165,
#  0.1760299625468165,
#  0.1760299625468165,
#  0.1760299625468165,
#  0.1760299625468165,
#  0.1760299625468165,
#  0.17228464419475656,
#  0.17228464419475656,
#  0.1760299625468165,
#  0.17228464419475656,
#  0.1797752808988764,
#  0.18352059925093633,
#  0.1760299625468165,
#  0.18352059925093633,
#  0.19850187265917604,
#  0.19850187265917604]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=22)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=22, p=2,
#            weights='uniform')

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[156   7]
#  [ 40  64]]

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8164794007490637

# %% [markdown]
# # decision tree model

# %%
from sklearn.model_selection import train_test_split

# %%
DATA1=DATA

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X = DATA.drop('Survived', axis=1)
y = DATA['Survived']

# %%
from sklearn.tree import DecisionTreeClassifier# import decision tree classifer

# %% [markdown]
# # create an instance of decisiontreeclassifier()called dtree and fit it yo the training data

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# # predictions and evaluation of desicion tree
# create predictions from the test set and create a classification report and a confusion matrix

# %%
predictions =dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.81      0.83       163
#           1       0.72      0.78      0.75       104
#
# avg / total       0.80      0.80      0.80       267

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[132  31]
#  [ 23  81]]

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8164794007490637

# %% [markdown]
# # training random forest model
# now its time to train our model
# create an instant of the random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# #prediction and evaluation
# lets predict off the y test values and evaluate our model
# predict the class of not.fully.paid for the x_test data

# %%
X = DATA.drop('Survived', axis=1)
y = DATA['Survived']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
predictions = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8164794007490637
